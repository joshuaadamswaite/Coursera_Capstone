# %% [markdown]
# # Applied Data Science Capstone Project

# %% [markdown]
# ## Some markdown to explain that this notebook will be mainly used for the capstone projec

# %%
import numpy as np
import pandas as pd 
text ="Hello Capstone Project Course"
print(text)
# Out:
# Hello Capstone Project Course
